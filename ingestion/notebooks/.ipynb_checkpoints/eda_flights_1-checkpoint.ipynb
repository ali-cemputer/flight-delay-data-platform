# %% [markdown]
# # BTS Airline On-Time Performance — EDA
# **Veri:** `data/sample/2025_01.csv` (Ocak 2025)
# **Amaç:** Veriyi üretim pipeline'ına sokmadan önce tanımak; null'ları, tip sorunlarını ve dağılımları anlamak.

# %% [markdown]
# ## Bölüm 0 — Setup
# Kütüphaneleri yüklüyoruz ve veriyi okuyoruz.
#
# ⚠️ **Önce terminalde çalıştır:** `uv add jupyter ipykernel matplotlib seaborn`

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings('ignore')

pd.set_option('display.max_columns', None)# see all cols
pd.set_option('display.max_rows', None)# see all rows
pd.set_option("display.float_format", lambda x: '%.3f' % x)
pd.set_option('display.width', 5000)

# Set visual style
plt.style.use('seaborn-v0_8')
sns.set_palette('husl')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 14
#      11 sns.set_palette('husl')
#      13 # Load data — low_memory=False prevents mixed-type warnings on large CSVs
# ---> 14 df = pd.read_csv('../data/sample/2025_01.csv', low_memory=False)
#      16 df.head()
#      17 df.columns
#
# ...

# %%
def load(year,month):
    data = pd.read_csv(f"../../data/raw/{year}/{year}_{month}.csv")
    return data

# %%
df = load(2023,1)
df.head()

# %% [markdown]
# ## Bölüm 1 — Genel Bakış
# Verinin boyutu, kolon yapısı, tipler ve temel istatistikler.

# %% [markdown]
# ### 1.1 Shape — Kaç satır, kaç kolon?

# %%
rows, cols = df.shape
print(f"Satır sayısı : {rows:,}")
print(f"Kolon sayısı : {cols}")
# Out:
# Satır sayısı : 539,747
# Kolon sayısı : 28

# %% [markdown]
# ### 1.2 Kolon Listesi — Gruplandırılmış

# %%
# Group columns by semantic category for easier navigation
column_groups = {
    'Time':          ['Year', 'Quarter', 'Month', 'DayofMonth', 'DayOfWeek', 'FlightDate'],
    'Airline':       ['Reporting_Airline', 'DOT_ID_Reporting_Airline', 'IATA_CODE_Reporting_Airline',
                      'Tail_Number', 'Flight_Number_Reporting_Airline'],
    'Origin':        ['OriginAirportID', 'OriginAirportSeqID', 'OriginCityMarketID',
                      'Origin', 'OriginCityName', 'OriginState', 'OriginStateFips',
                      'OriginStateName', 'OriginWac'],
    'Destination':   ['DestAirportID', 'DestAirportSeqID', 'DestCityMarketID',
                      'Dest', 'DestCityName', 'DestState', 'DestStateFips',
                      'DestStateName', 'DestWac'],
    'Departure':     ['CRSDepTime', 'DepTime', 'DepDelay', 'DepDelayMinutes',
                      'DepDel15', 'DepartureDelayGroups', 'DepTimeBlk', 'TaxiOut', 'WheelsOff'],
    'Arrival':       ['WheelsOn', 'TaxiIn', 'CRSArrTime', 'ArrTime', 'ArrDelay',
                      'ArrDelayMinutes', 'ArrDel15', 'ArrivalDelayGroups', 'ArrTimeBlk'],
    'Cancel/Divert': ['Cancelled', 'CancellationCode', 'Diverted'],
    'Delay Cause':   ['CarrierDelay', 'WeatherDelay', 'NASDelay', 'SecurityDelay', 'LateAircraftDelay'],
}

for group, cols_list in column_groups.items():
    existing = [c for c in cols_list if c in df.columns]
    print(f"\n{'='*50}")
    print(f"  {group} ({len(existing)} kolon)")
    print(f"{'='*50}")
    print(', '.join(existing))

# Show columns not captured in the groups above
grouped   = [c for g in column_groups.values() for c in g]
ungrouped = [c for c in df.columns if c not in grouped]
print(f"\n--- Gruplanmamış ({len(ungrouped)} kolon) ---")
print(', '.join(ungrouped))
# Out:
# ...
#   Time (0 kolon)
# ...
#
#
# ...
#   Airline (0 kolon)
# ...
#
#
# ...
#   Origin (0 kolon)
# ...
#
#
# ...
#   Destination (0 kolon)
# ...
#
#
# ...
#   Departure (0 kolon)
# ...
#
#
# ...
#   Arrival (0 kolon)
# ...
#
#
# ...
#   Cancel/Divert (0 kolon)
# ...
#
#
# ...
#   Delay Cause (0 kolon)
# ...
#
#
# --- Gruplanmamış (28 kolon) ---
# YEAR, MONTH, DAY_OF_WEEK, FL_DATE, OP_UNIQUE_CARRIER, ORIGIN, ORIGIN_CITY_NAME, DEST, DEST_CITY_NAME, CRS_DEP_TIME, DEP_TIME, DEP_DELAY, TAXI_OUT, TAXI_IN, CRS_ARR_TIME, ARR_TIME, ARR_DELAY, CANCELLED, CANCELLATION_CODE, DIVERTED, ACTUAL_ELAPSED_TIME, AIR_TIME, DISTANCE, CARRIER_DELAY, WEATHER_DELAY, NAS_DELAY, SECURITY_DELAY, LATE_AIRCRAFT_DELAY

# %% [markdown]
# ### 1.3 Veri Tipleri — object gelen sayısal kolonlar var mı?

# %%
dtype_df        = pd.DataFrame({'dtype': df.dtypes, 'sample': df.iloc[0]})
suspect_numeric = dtype_df[dtype_df['dtype'] == 'object'].copy()


print(df.dtypes)

print("\nobject tipindeki kolonlar:")
print(suspect_numeric[['dtype', 'sample']].to_string())
# Out:
# Tüm kolon tipleri (özet):
# float64    16
# str         7
# int64       5
# Name: count, dtype: int64
#
# object tipindeki kolonlar:
# Empty DataFrame
# Columns: [dtype, sample]
# Index: []

# %% [markdown]
# ### 1.4 Bellek Kullanımı

# %%
# deep=True counts actual string memory, not just pointers
memory_mb = df.memory_usage(deep=True).sum() / 1024 ** 2
print(f"DataFrame bellek kullanımı: {memory_mb:.1f} MB")
# Out:
# DataFrame bellek kullanımı: 282.8 MB

# %% [markdown]
# ### 1.5 Temel İstatistikler — describe()

# %%
# Numeric columns only; transpose so rows = columns for easy reading
df.describe().T[['min', 'mean', 'max', 'std']].round(2)
# Out:
#                         min     mean     max     std
# YEAR                 2025.0  2025.00  2025.0    0.00
# MONTH                   1.0     1.00     1.0    0.00
# DAY_OF_WEEK             1.0     4.02     7.0    1.93
# CRS_DEP_TIME            5.0  1315.74  2359.0  480.56
# DEP_TIME                1.0  1320.87  2400.0  491.90
# DEP_DELAY             -50.0    10.34  3298.0   54.33
# TAXI_OUT                1.0    19.06   182.0   11.23
# TAXI_IN                 1.0     8.32   212.0    6.80
# CRS_ARR_TIME            1.0  1502.66  2359.0  502.48
# ARR_TIME                1.0  1482.31  2400.0  520.04
# ARR_DELAY             -87.0     3.76  3282.0   56.85
# CANCELLED               0.0     0.03     1.0    0.17
# DIVERTED                0.0     0.00     1.0    0.05
# ACTUAL_ELAPSED_TIME    16.0   145.40   749.0   73.89
# AIR_TIME                8.0   118.04   706.0   72.04
# DISTANCE               31.0   843.21  5095.0  599.09
# CARRIER_DELAY           0.0    25.59  3282.0   76.79
# ...

# %% [markdown]
# ## Bölüm 2 — Null / Eksik Veri Analizi
# Null'ların nerede ve neden oluştuğunu anlamak, pipeline'da doğru strateji kurmak için kritik.

# %% [markdown]
# ### 2.1 Null Sayısı ve Oranı

# %%
null_counts = df.isnull().sum()
null_pct    = (null_counts / len(df) * 100).round(2)

null_df = (
    pd.DataFrame({'null_count': null_counts, 'null_pct': null_pct})
    .query('null_count > 0')
    .sort_values('null_pct', ascending=False)
)

print(f"Null içeren kolon sayısı: {len(null_df)} / {len(df.columns)}\n")
print(null_df.to_string())
# Out:
# Null içeren kolon sayısı: 14 / 28
#
#                      null_count  null_pct
# CANCELLATION_CODE        523435     96.98
# LATE_AIRCRAFT_DELAY      441617     81.82
# WEATHER_DELAY            441617     81.82
# NAS_DELAY                441617     81.82
# CARRIER_DELAY            441617     81.82
# SECURITY_DELAY           441617     81.82
# AIR_TIME                  17478      3.24
# ARR_DELAY                 17478      3.24
# ACTUAL_ELAPSED_TIME       17478      3.24
# TAXI_IN                   16580      3.07
# ARR_TIME                  16580      3.07
# TAXI_OUT                  16227      3.01
# DEP_DELAY                 15923      2.95
# DEP_TIME                  15886      2.94

# %% [markdown]
# ### 2.2 Isı Haritası — Null Dağılımı
# _İlk 10.000 satır üzerinde — büyük veri için yeterli temsil._

# %%
cols_with_nulls = null_df.index.tolist()
sample_df       = df.sample(10_000, random_state=42)

fig, ax = plt.subplots(figsize=(14, 6))
sns.heatmap(
    sample_df[cols_with_nulls].isnull(),
    yticklabels=False,
    cbar=False,
    cmap='viridis',
    ax=ax
)
ax.set_title('Null Dağılımı (10k satır sample) — Sarı = Null', fontsize=13)
ax.set_xlabel('Kolonlar')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 2.3 Null Grupları — Beklenen mi, Beklenmedik mi?

# %%
# Delay columns should be ~100% null for cancelled flights
delay_cols    = ['CarrierDelay', 'WeatherDelay', 'NASDelay', 'SecurityDelay', 'LateAircraftDelay']
cancelled     = df[df['CANCELLED'] == 1]
not_cancelled = df[df['CANCELLED'] == 0]

print("--- Delay kolonları — iptal uçuşlarda null oranı (beklenen: ~%100) ---")
print((cancelled[delay_cols].isnull().mean() * 100).round(2))

print("\n--- Delay kolonları — gerçekleşen uçuşlarda null oranı (beklenen: düşük) ---")
print((not_cancelled[delay_cols].isnull().mean() * 100).round(2))
# Out:
# --- Delay kolonları — iptal uçuşlarda null oranı (beklenen: ~%100) ---
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 7
#       4 not_cancelled = df[df['CANCELLED'] == 0]
#       6 print("--- Delay kolonları — iptal uçuşlarda null oranı (beklenen: ~%100) ---")
# ----> 7 print((cancelled[delay_cols].isnull().mean() * 100).round(2))
#       9 print("\n--- Delay kolonları — gerçekleşen uçuşlarda null oranı (beklenen: düşük) ---")
#      10 print((not_cancelled[delay_cols].isnull().mean() * 100).round(2))
#
# File ~/bd_project/.venv/lib/python3.13/site-packages/pandas/core/frame.py:4384, in DataFrame.__getitem__(self, key)
#    4382     if is_iterator(key):
#    4383         key = list(key)
# -> 4384     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4386 # take() does not accept boolean indexers
# ...

# %%
# CancellationCode: populated for cancelled, null for the rest
code_in_cancelled     = df[df['Cancelled'] == 1]['CancellationCode'].isnull().mean() * 100
code_in_not_cancelled = df[df['Cancelled'] == 0]['CancellationCode'].isnull().mean() * 100

print("CancellationCode null oranı:")
print(f"  İptal edilenlerde   : {code_in_cancelled:.1f}%  (beklenen: ~0%)")
print(f"  İptal edilmeyenlerde: {code_in_not_cancelled:.1f}%  (beklenen: ~100%)")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/bd_project/.venv/lib/python3.13/site-packages/pandas/core/indexes/base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7676, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Cancelled'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 2
# ...

# %%
# DepTime / ArrTime: should be null for cancelled flights
time_null = df[df['Cancelled'] == 1][['DepTime', 'ArrTime']].isnull().mean() * 100

print("DepTime / ArrTime — iptal uçuşlarda null oranı (beklenen: ~%100):")
print(time_null.round(1))

# %% [markdown]
# ### 2.4 Kritik Null'lar — Pipeline İçin İşaretlenenler

# %%
# Null rate in non-cancelled flights — these are unexpected and need handling
critical_nulls = (
    not_cancelled.isnull().mean() * 100
    .round(2)
)
critical_nulls = critical_nulls[critical_nulls > 5].sort_values(ascending=False)

print("Gerçekleşen uçuşlarda >%5 null olan kolonlar (pipeline riski):")
print(critical_nulls.to_string())

# %% [markdown]
# ## Bölüm 3 — Kolon Bazlı Dağılımlar

# %% [markdown]
# ### 3.1 Zaman Kolonları

# %%
# Should be constant for a single-month file
print(f"Year  unique: {sorted(df['YEAR'].unique())}")
print(f"Month unique: {sorted(df['MONTH'].unique())}")
# Out:
# Year  unique: [np.int64(2025)]
# Month unique: [np.int64(1)]

# %%
# 1=Monday … 7=Sunday
dow_labels = {1:'Pzt', 2:'Sal', 3:'Çar', 4:'Per', 5:'Cum', 6:'Cmt', 7:'Paz'}
dow_counts = df['DAY_OF_WEEK'].value_counts().sort_index()
dow_counts.index = [dow_labels[i] for i in dow_counts.index]

fig, ax = plt.subplots(figsize=(8, 4))
dow_counts.plot(kind='bar', ax=ax, edgecolor='white')
ax.set_title('Güne Göre Uçuş Sayısı', fontsize=13)
ax.set_xlabel('Gün')
ax.set_ylabel('Uçuş Sayısı')
ax.tick_params(axis='x', rotation=0)
plt.tight_layout()
plt.show()

# %%
daily = df.groupby('FL_DATE').size().reset_index(name='count')

fig, ax = plt.subplots(figsize=(12, 4))
ax.plot(daily['FL_DATE'], daily['count'], marker='o', markersize=3)
ax.set_title('Günlük Uçuş Sayısı — Ocak 2025', fontsize=13)
ax.set_xlabel('Tarih')
ax.set_ylabel('Uçuş Sayısı')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 3.2 Havayolu ve Rota

# %%
print(f"Toplam farklı havayolu: {df['Reporting_Airline'].nunique()}")

airline_counts = df['Reporting_Airline'].value_counts().head(10)

fig, ax = plt.subplots(figsize=(9, 4))
airline_counts.plot(kind='bar', ax=ax, edgecolor='white')
ax.set_title('Top 10 Havayolu — Uçuş Sayısı', fontsize=13)
ax.set_xlabel('Havayolu Kodu')
ax.set_ylabel('Uçuş Sayısı')
ax.tick_params(axis='x', rotation=0)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/bd_project/.venv/lib/python3.13/site-packages/pandas/core/indexes/base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7676, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Reporting_Airline'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[19], line 1
# ...

# %%
print(f"Farklı origin havalimanı: {df['ORIGIN'].nunique()}")
print(f"Farklı dest havalimanı  : {df['DEST'].nunique()}")

top_origins = df['ORIGIN'].value_counts().head(10)

fig, ax = plt.subplots(figsize=(9, 4))
top_origins.plot(kind='bar', ax=ax, edgecolor='white')
ax.set_title('Top 10 Origin Havalimanı', fontsize=13)
ax.set_xlabel('Havalimanı Kodu')
ax.set_ylabel('Uçuş Sayısı')
ax.tick_params(axis='x', rotation=0)
plt.tight_layout()
plt.show()
# Out:
# Farklı origin havalimanı: 329
# Farklı dest havalimanı  : 329

# %% [markdown]
# ### 3.3 Süre ve Mesafe

# %%
fig, ax = plt.subplots(figsize=(9, 4))
df['Distance'].dropna().hist(bins=60, ax=ax, edgecolor='none')
ax.set_title('Distance Dağılımı (mil)', fontsize=13)
ax.set_xlabel('Mesafe (mil)')
ax.set_ylabel('Uçuş Sayısı')
plt.tight_layout()
plt.show()

print(f"Min: {df['Distance'].min():.0f} mil")
print(f"Max: {df['Distance'].max():.0f} mil")
print(f"Ort: {df['Distance'].mean():.0f} mil")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/bd_project/.venv/lib/python3.13/site-packages/pandas/core/indexes/base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7676, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Distance'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[24], line 2
# ...

# %%
# Difference = taxi time (ground movements)
sample = df[['AirTime', 'ActualElapsedTime']].dropna().sample(10_000, random_state=42)

fig, ax = plt.subplots(figsize=(7, 5))
ax.scatter(sample['AirTime'], sample['ActualElapsedTime'], alpha=0.2, s=5)
ax.set_title('AirTime vs ActualElapsedTime\n(fark = TaxiOut + TaxiIn süresi)', fontsize=12)
ax.set_xlabel('AirTime (dakika)')
ax.set_ylabel('ActualElapsedTime (dakika)')
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[25], line 2
#       1 # Difference = taxi time (ground movements)
# ----> 2 sample = df[['AirTime', 'ActualElapsedTime']].dropna().sample(10_000, random_state=42)
#       4 fig, ax = plt.subplots(figsize=(7, 5))
#       5 ax.scatter(sample['AirTime'], sample['ActualElapsedTime'], alpha=0.2, s=5)
#
# File ~/bd_project/.venv/lib/python3.13/site-packages/pandas/core/frame.py:4384, in DataFrame.__getitem__(self, key)
#    4382     if is_iterator(key):
#    4383         key = list(key)
# -> 4384     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4386 # take() does not accept boolean indexers
#    4387 if getattr(indexer, "dtype", None) == bool:
#
# File ~/bd_project/.venv/lib/python3.13/site-packages/pandas/core/indexes/base.py:6302, in Index._get_indexer_strict(self, key, axis_name)
#    6299 else:
# ...

# %% [markdown]
# ### 3.4 Departure Zaman Dağılımı
# ⚠️ **Not:** `CRSDepTime` / `CRSArrTime` kolonları `0–2359` integer formatında gelir (örn. 930 = 09:30). Pipeline'da `//100` ile saat, `%100` ile dakika ayrıştırılmalı.

# %%
# Extract hour: 1435 -> 14
dep_hour    = (df['CRSDepTime'].dropna() // 100).astype(int)
dep_hour    = dep_hour[dep_hour <= 23]   # drop edge-case 2400 rows
hour_counts = dep_hour.value_counts().sort_index()

fig, ax = plt.subplots(figsize=(12, 4))
hour_counts.plot(kind='bar', ax=ax, edgecolor='white')
ax.set_title('CRSDepTime — Saate Göre Planlanmış Kalkış Yoğunluğu', fontsize=13)
ax.set_xlabel('Saat (yerel)')
ax.set_ylabel('Uçuş Sayısı')
ax.tick_params(axis='x', rotation=0)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Bölüm 4 — İptal ve Divert Analizi

# %%
#cancel_rate = df['CANCELLATION_CODE'].mean() * 100
divert_rate = df['DIVERTED'].mean() * 100
#print(f"İptal oranı : {cancel_rate:.2f}%")
print(f"Divert oranı: {divert_rate:.2f}%")
# Out:
# Divert oranı: 0.22%

# %%
# A=Carrier  B=Weather  C=NAS  D=Security
code_map    = {'A': 'Carrier (A)', 'B': 'Weather (B)', 'C': 'NAS (C)', 'D': 'Security (D)'}
code_counts = df['CANCELLATION_CODE'].dropna().map(code_map).value_counts()

fig, ax = plt.subplots(figsize=(7, 4))
code_counts.plot(kind='bar', ax=ax, edgecolor='white')
ax.set_title('İptal Nedenleri (CancellationCode)', fontsize=13)
ax.set_xlabel('Neden')
ax.set_ylabel('İptal Sayısı')
ax.tick_params(axis='x', rotation=0)
plt.tight_layout()
plt.show()

# %%
# All delay columns should be null on cancelled rows
delay_cols   = ['CarrierDelay', 'WeatherDelay', 'NASDelay', 'SecurityDelay', 'LateAircraftDelay']
all_null_pct = df[df['Cancelled'] == 1][delay_cols].isnull().all(axis=1).mean() * 100
print(f"İptal uçuşlarda tüm delay kolonları null olan satır oranı: {all_null_pct:.1f}%")
print("(Beklenen: ~%100 — gecikme verisi hiç oluşmamış)")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/bd_project/.venv/lib/python3.13/site-packages/pandas/core/indexes/base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7676, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Cancelled'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[31], line 3
# ...

# %%
# Normalized cancellation rate per airline
airline_cancel = (
    df.groupby('Reporting_Airline')['Cancelled']
    .agg(['sum', 'count'])
    .assign(cancel_rate=lambda x: x['sum'] / x['count'] * 100)
    .sort_values('cancel_rate', ascending=False)
    .head(10)
)

fig, ax = plt.subplots(figsize=(10, 4))
airline_cancel['cancel_rate'].plot(kind='bar', ax=ax, edgecolor='white')
ax.set_title('Havayoluna Göre İptal Oranı (%) — Top 10', fontsize=13)
ax.set_xlabel('Havayolu')
ax.set_ylabel('İptal Oranı (%)')
ax.tick_params(axis='x', rotation=0)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[32], line 3
#       1 # Normalized cancellation rate per airline
#       2 airline_cancel = (
# ----> 3     df.groupby('Reporting_Airline')['Cancelled']
#       4     .agg(['sum', 'count'])
#       5     .assign(cancel_rate=lambda x: x['sum'] / x['count'] * 100)
#       6     .sort_values('cancel_rate', ascending=False)
#       7     .head(10)
#       8 )
#      10 fig, ax = plt.subplots(figsize=(10, 4))
#      11 airline_cancel['cancel_rate'].plot(kind='bar', ax=ax, edgecolor='white')
#
# File ~/bd_project/.venv/lib/python3.13/site-packages/pandas/util/_decorators.py:336, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     330 if len(args) > num_allow_args:
#     331     warnings.warn(
#     332         msg.format(arguments=_format_argument_list(allow_args)),
# ...

# %% [markdown]
# ## Bölüm 5 — Gecikme Analizi

# %%
# is_delayed definition used in the pipeline
delayed_rate = (df['ArrDelay'] > 15).mean() * 100
print(f"ArrDelay > 15 dk olan uçuş oranı (is_delayed): {delayed_rate:.2f}%")

# %%
# Clip to -60/+180 so extreme outliers don't squash the histogram
arr_delay = df['ArrDelay'].dropna()
neg_pct   = (arr_delay < 0).mean() * 100

fig, ax = plt.subplots(figsize=(10, 4))
arr_delay.clip(-60, 180).hist(bins=80, ax=ax, edgecolor='none')
ax.axvline(0,  color='red',    linestyle='--', linewidth=1.2, label='0 dk')
ax.axvline(15, color='orange', linestyle='--', linewidth=1.2, label='15 dk eşiği')
ax.set_title('ArrDelay Dağılımı (−60 / +180 dk arası kırpılmış)', fontsize=13)
ax.set_xlabel('Varış Gecikmesi (dk)')
ax.set_ylabel('Uçuş Sayısı')
ax.legend()
plt.tight_layout()
plt.show()

print(f"Negatif ArrDelay oranı (erken iniş): {neg_pct:.1f}%")

# %%
def categorize_delay(x):
    if pd.isna(x):  return 'Unknown'
    elif x <= 0:    return 'No Delay'
    elif x <= 15:   return 'Minor (1-15 dk)'
    elif x <= 60:   return 'Major (16-60 dk)'
    else:           return 'Severe (60+ dk)'

cat_order  = ['No Delay', 'Minor (1-15 dk)', 'Major (16-60 dk)', 'Severe (60+ dk)', 'Unknown']
delay_cats = df['ArrDelay'].apply(categorize_delay).value_counts().reindex(cat_order, fill_value=0)
delay_pct  = (delay_cats / len(df) * 100).round(2)

print(pd.DataFrame({'count': delay_cats, 'pct': delay_pct}).to_string())

# %%
# Total delay minutes contributed by each cause
delay_cols   = ['CarrierDelay', 'WeatherDelay', 'NASDelay', 'SecurityDelay', 'LateAircraftDelay']
cause_totals = df[delay_cols].sum()
cause_pct    = (cause_totals / cause_totals.sum() * 100).round(2)

fig, ax = plt.subplots(figsize=(8, 4))
cause_pct.plot(kind='bar', ax=ax, edgecolor='white')
ax.set_title('Gecikme Nedenlerinin Payı (Toplam Gecikme Dakikası %)', fontsize=13)
ax.set_xlabel('Gecikme Nedeni')
ax.set_ylabel('%')
ax.tick_params(axis='x', rotation=20)
plt.tight_layout()
plt.show()

# %%
corr_cols = ['CarrierDelay', 'WeatherDelay', 'NASDelay', 'SecurityDelay', 'LateAircraftDelay', 'ArrDelay']
corr      = df[corr_cols].corr()

fig, ax = plt.subplots(figsize=(7, 5))
sns.heatmap(corr, annot=True, fmt='.2f', cmap='coolwarm', center=0, ax=ax)
ax.set_title('Delay Kolonları Korelasyon Matrisi', fontsize=13)
plt.tight_layout()
plt.show()

# %%
# Sample 10k — full dataset makes scatter unreadable
sample = df[['DepDelay', 'ArrDelay']].dropna().sample(10_000, random_state=42)

fig, ax = plt.subplots(figsize=(7, 5))
ax.scatter(sample['DepDelay'], sample['ArrDelay'], alpha=0.15, s=5)
ax.axhline(0, color='red', linestyle='--', linewidth=0.8)
ax.axvline(0, color='red', linestyle='--', linewidth=0.8)
ax.set_title('DepDelay vs ArrDelay (10k sample)', fontsize=13)
ax.set_xlabel('Kalkış Gecikmesi (dk)')
ax.set_ylabel('Varış Gecikmesi (dk)')
plt.tight_layout()
plt.show()

# %%
avg_delay = (
    df.groupby('Reporting_Airline')['ArrDelay']
    .mean()
    .sort_values(ascending=False)
    .head(10)
)

fig, ax = plt.subplots(figsize=(9, 4))
avg_delay.plot(kind='bar', ax=ax, edgecolor='white')
ax.set_title('Havayoluna Göre Ortalama Varış Gecikmesi — Top 10', fontsize=13)
ax.set_xlabel('Havayolu')
ax.set_ylabel('Ort. ArrDelay (dk)')
ax.tick_params(axis='x', rotation=0)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Bölüm 6 — Özet Bulgular
#
# ### Kritik Bulgular
#
# **Bölüm 1 — Genel Bakış**
# - Beklenen boyut: ~500k–700k satır, ~110 kolon.
# - `object` tipinde gelen sayısal sütunlar transform adımında cast edilmeli.
# - `CRSDepTime` / `CRSArrTime` `0–2359` integer formatında — pipeline'da `//100` ile saat, `%100` ile dakika çıkarılmalı.
#
# **Bölüm 2 — Null Analizi**
# - Delay kolonlarındaki null'lar beklenen: iptal uçuşlarda gecikme verisi oluşmuyor → transform'da bu null'ları olduğu gibi koru.
# - `CancellationCode` iptal olmayan satırlarda null → staging'de bu kolon `nullable` olmalı.
# - `DepTime` / `ArrTime` iptal uçuşlarda null → sentinel değerle doldurmak yerine null bırak.
#
# **Bölüm 3 — Dağılımlar**
# - `Year` ve `Month` sabitse partition metadata olarak tutulabilir, kolon olarak taşınmayabilir.
# - `Distance` sağa çarpık — min değer kontrol edilmeli, 0 veya negatif olmamalı.
#
# **Bölüm 4 — İptal**
# - İptal oranı genellikle %1–3. Ocak kış ayı olduğu için Weather (B) kodunun ağırlıklı olması beklenir.
# - Havayoluna göre normalize edilmiş oran SLA takibinde kullanılabilir.
#
# **Bölüm 5 — Gecikme**
# - `is_delayed` = `ArrDelay > 15` → pipeline'da boolean kolon olarak türetilecek.
# - `DepDelay` ile `ArrDelay` yüksek korelasyon — regresyon modeli için güçlü feature.
# - `LateAircraftDelay` genellikle en yüksek paya sahip neden — zincir gecikme etkisi.
#
# ---
#
# ### Transform Adımı İçin Yapılacaklar (`transform_load_staging.py`)
#
# 1. **Tip dönüşümleri:** `object` kolonları `pd.to_numeric(errors='coerce')` ile cast et; başarısız olanları logla.
# 2. **Zaman dönüşümü:** `CRSDepTime`, `CRSArrTime`, `DepTime`, `ArrTime` → HH:MM veya `TimestampType`.
# 3. **Türetilmiş kolonlar:** `is_delayed` (ArrDelay > 15), `delay_category`, `taxi_time` (ActualElapsedTime − AirTime).
# 4. **Null stratejisi:** Delay kolonları iptal uçuşlarda null kalmalı — 0 ile doldurma.
# 5. **Aykırı değer kontrolü:** `Distance <= 0`, `ArrDelay < -120` veya `> 600` gibi değerleri logla.
# 6. **Partition:** `FlightDate` ile Parquet partition → okuma hızı artar.
# 7. **Sütun seçimi:** ~110 kolonun tamamı staging'e gitmek zorunda değil — business-critical ~30–40 kolon belirlenmeli.
